# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install nltk pandas openpyxl
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os
import nltk
from collections import Counter
import string
import pandas as pd
from tqdm import tqdm

def load_text(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

def preprocess_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    words = nltk.word_tokenize(text)
    return words

def remove_stopwords(words):
    stopwords = set(nltk.corpus.stopwords.words('english'))
    return [word for word in words if word not in stopwords]

def get_top_keywords(words, n=20):
    counter = Counter(words)
    return [keyword for keyword, freq in counter.most_common(n)]

def process_files_in_directory(directory_path):
    results = []
    for filename in tqdm(os.listdir(directory_path)):
        if filename.endswith('.txt'):
            file_path = os.path.join(directory_path, filename)
            text = load_text(file_path)
            words = preprocess_text(text)
            words = remove_stopwords(words)
            top_keywords = get_top_keywords(words)

            result_row = [filename] + top_keywords
            results.append(result_row)

    return results

def main(directory_path, output_file):
    nltk.download('punkt')
    nltk.download('stopwords')

    results = process_files_in_directory(directory_path)

    column_names = ['Filename'] + [f'Keyword_{i}' for i in range(1, 21)]

    df = pd.DataFrame(results, columns=column_names)

    df.to_excel(output_file, index=False)
    print(f"Results saved to {output_file}")
directory_path = '/content/drive/MyDrive/model/txt_token'
output_file = 'top_keywords.xlsx'
main(directory_path, output_file)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 100%|██████████| 1373/1373 [00:58<00:00, 23.58it/s]
# Results saved to top_keywords.xlsx

# %%
def read_excel_file(file_path):
    df = pd.read_excel(file_path)
    return df

file_path = 'top_keywords.xlsx'
df = read_excel_file(file_path)
df
# Out:
#                                                Filename    Keyword_1  \
# 0            Delphy DPY whitepapers - whitepaper.io.txt          NaN
# 1        DecentBet DBET whitepapers - whitepaper.io.txt        house
# 2            Daneel DAN whitepapers - whitepaper.io.txt       daneel
# 3              DATA DTA whitepapers - whitepaper.io.txt         data
# 4           Darcrus MER whitepapers - whitepaper.io.txt         data
# ...                                                 ...          ...
# 1368            DAD DAD whitepapers - whitepaper.io.txt         user
# 1369           DAEX DAX whitepapers - whitepaper.io.txt     clearing
# 1370        Decimal DEL whitepapers - whitepaper.io.txt         coin
# 1371    DigitalBits XDB whitepapers - whitepaper.io.txt  digitalbits
# 1372  Dfyn Network DFYN whitepapers - whitepaper.io.txt         dfyn
#
#         Keyword_2 Keyword_3   Keyword_4    Keyword_5    Keyword_6  \
# 0             NaN       NaN         NaN          NaN          NaN
# 1             bet  platform      decent         user       credit
# 2           token        io         www   whitepaper  information
# 3           token      node        user   blockchain   foundation
# 4          public       use   dappsheet      company     customer
# ...           ...       ...         ...          ...          ...
# 1368  advertising       dad  blockchain    metaverse     industry
# 1369         daex  exchange       asset   technology         user
# 1370      decimal     token         del  transaction         user
# 1371        token   program       asset       server  transaction
# 1372      current   tnerruc       token      working          ruo
#
#            Keyword_7       Keyword_8      Keyword_9  ...  Keyword_11  \
# 0                NaN             NaN            NaN  ...         NaN
# 1               game           would           dbet  ...      profit
# 2               user  cryptocurrency       investor  ...     service
# 3                 ad          mobile  decentralized  ...          ai
# 4            private            site            bet  ...    platform
# ...              ...             ...            ...  ...         ...
# 1368           chain            game     advertiser  ...         new
# 1369  cryptocurrency     distributed          based  ...     trading
# 1370      blockchain         network        project  ...    contract
# 1371         loyalty         network           goal  ...  blockchain
# 1372            maet        serutaef           team  ...     pamdaor
#
#       Keyword_12  Keyword_13  Keyword_14   Keyword_15  Keyword_16  \
# 0            NaN         NaN         NaN          NaN         NaN
# 1        session      casino    gambling   blockchain    ethereum
# 2     blockchain    platform        sale      company         use
# 3          trust       based     powered     alliance  whitepaper
# 4           node     version     darcrus         case     release
# ...          ...         ...         ...          ...         ...
# 1368     content       token        data  development       based
# 1369      wallet    solution     service   whitepaper       chain
# 1370     service      number       chain         http      custom
# 1371  compliance  federation          db      account        http
# 1372     feature     roadmap  segnellahc   scimonekot    solution
#
#         Keyword_17  Keyword_18   Keyword_19    Keyword_20
# 0              NaN         NaN          NaN           NaN
# 1             page       based     contract         sport
# 2     intelligence  investment         data     assistant
# 3          network           n        fraud        issuer
# 4             date    november      revised      december
# ...            ...         ...          ...           ...
# 1368          also      number  information      delivery
# 1369    blockchain   technical            v       digital
# 1370     validator     reserve        issue   blockchains
# 1371    hotelbrand       point      digital        system
# 1372          defi   challenge      utility  architecture
#
# [1373 rows x 21 columns]

# %%
def read_excel_file(file_path):
    df = pd.read_excel(file_path)
    return df

file_path = 'top_keywords.xlsx'
df = read_excel_file(file_path)

output_file_path = '/content/drive/MyDrive/model/aved_keywords.xlsx'
df.to_excel(output_file_path, index=False)

output_file_path
# Out:
# '/content/drive/MyDrive/model/aved_keywords.xlsx'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN
import numpy as np
def read_excel_file(file_path):
    df = pd.read_excel(file_path)
    return df

file_path = 'top_keywords.xlsx'
df = read_excel_file(file_path)

df['keywords'] = df.apply(lambda row: ' '.join([str(row[f'Keyword_{i}']) for i in range(1, 21)]), axis=1)

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['keywords'])

dbscan = DBSCAN(eps=0.5, min_samples=2, metric='cosine')
clusters = dbscan.fit_predict(X)

df['Cluster'] = clusters
output_file_path = '/content/drive/MyDrive/model/keywords_with_clusters.xlsx'
df.to_excel(output_file_path, index=False)

output_file_path
# Out:
# '/content/drive/MyDrive/model/saved_keywords_with_clusters.xlsx'
